# %%
import pandas as pd
import numpy as np

df = pd.read_csv('combined_dataset.csv')

# %%
# The first step is to semantically standardize each column, meaning that we ensure that every column has a stable and efficient set of values

# The age column already has numerical values ranged 0-100 so no need for standardizing
print("The current age values are: ")
df['age'].unique()
# Out:
# The current age values are:
# array([ 8, 55, 77, 75, 79, 53, 52, 74, 68, 58, 45, 34,  9, 78, 60, 64, 61,
#        62, 67, 71, 66, 38, 54, 82, 63, 49, 76, 31, 36, 17, 44, 56, 26, 47,
#        80, 48, 51, 35, 87, 41, 22, 69, 59, 57, 65, 83, 92, 33, 46, 50, 70,
#        85, 40, 73, 10, 86, 72, 14, 21, 39, 94, 43, 90, 89, 13, 30, 81, 84,
#        88, 37, 32, 16, 29, 24, 42, 20, 23, 28, 27, 91, 18, 12, 25,  6, 93,
#        99, 95])

# %%
# The sex column needs to be standardized as there are both uppercase and lowercase gender describing values
# I have identified multiple columns in this dataset with the same issue so we can just build a function to convert lowercase from uppercase and apply it to each column

def standardize_case_simple(df, column_name):
    
    # 1. Print current unique values
    print(f"The current {column_name} values are: ")
    print(df[column_name].unique())
    
    # 2. Apply lowercasing (The transformation)
    df[column_name] = df[column_name].str.lower()
    
    # 3. Print new unique values
    print("================================")
    print(f"The new {column_name} values are: ")
    print(df[column_name].unique())
    
    return df

# I will also create an array of all the columns that need to be transformed into lowercase that will be traversed and mapped
columns_lowercase = ['sex','alcohol_consumption','smoking','cancer_history','skin_cancer_history','background_father', 'background_mother', 'bleed', 'hurt', 'itch', 'changed', 'grew','elevation', 'biopsed', 'has_piped_water','has_sewage_system', 'pesticide']
for col in columns_lowercase:
    print(f"| PROCESSING: {col.upper()}")
    df = standardize_case_simple(df, col)
# Out:
# | PROCESSING: SEX
# The current sex values are:
# ['unknown' 'FEMALE' 'MALE' 'female' 'male']
# ================================
# The new sex values are:
# ['unknown' 'female' 'male']
# | PROCESSING: ALCOHOL_CONSUMPTION
# The current alcohol_consumption values are:
# ['unknown' 'False' 'True']
# ================================
# The new alcohol_consumption values are:
# ['unknown' 'false' 'true']
# | PROCESSING: SMOKING
# The current smoking values are:
# ['unknown' 'False' 'True']
# ================================
# The new smoking values are:
# ['unknown' 'false' 'true']
# | PROCESSING: CANCER_HISTORY
# The current cancer_history values are:
# ['unknown' 'True' 'False']
# ================================
# The new cancer_history values are:
# ['unknown' 'true' 'false']
# | PROCESSING: SKIN_CANCER_HISTORY
# The current skin_cancer_history values are:
# ['unknown' 'True' 'False']
# ================================
# The new skin_cancer_history values are:
# ['unknown' 'true' 'false']
# | PROCESSING: BACKGROUND_FATHER
# The current background_father values are:
# ['unknown' 'POMERANIA' 'GERMANY' 'BRAZIL' 'NETHERLANDS' 'ITALY' 'POLAND'
#  'UNK' 'PORTUGAL' 'BRASIL' 'CZECH' 'AUSTRIA' 'SPAIN' 'ISRAEL']
# ================================
# The new background_father values are:
# ['unknown' 'pomerania' 'germany' 'brazil' 'netherlands' 'italy' 'poland'
#  'unk' 'portugal' 'brasil' 'czech' 'austria' 'spain' 'israel']
# | PROCESSING: BACKGROUND_MOTHER
# The current background_mother values are:
# ['unknown' 'POMERANIA' 'ITALY' 'GERMANY' 'BRAZIL' 'UNK' 'POLAND' 'NORWAY'
#  'PORTUGAL' 'NETHERLANDS' 'FRANCE' 'SPAIN']
# ================================
# The new background_mother values are:
# ['unknown' 'pomerania' 'italy' 'germany' 'brazil' 'unk' 'poland' 'norway'
#  'portugal' 'netherlands' 'france' 'spain']
# | PROCESSING: BLEED
# The current bleed values are:
# ['FALSE' 'TRUE' 'UNK' 'unknown']
# ================================
# The new bleed values are:
# ['false' 'true' 'unk' 'unknown']
# | PROCESSING: HURT
# The current hurt values are:
# ['FALSE' 'TRUE' 'UNK' 'unknown']
# ================================
# The new hurt values are:
# ['false' 'true' 'unk' 'unknown']
# | PROCESSING: ITCH
# The current itch values are:
# ['FALSE' 'TRUE' 'UNK' 'unknown']
# ================================
# The new itch values are:
# ['false' 'true' 'unk' 'unknown']
# | PROCESSING: CHANGED
# The current changed values are:
# ['FALSE' 'TRUE' 'UNK' 'unknown']
# ================================
# The new changed values are:
# ['false' 'true' 'unk' 'unknown']
# | PROCESSING: GREW
# The current grew values are:
# ['FALSE' 'TRUE' 'UNK' 'unknown']
# ================================
# The new grew values are:
# ['false' 'true' 'unk' 'unknown']
# | PROCESSING: ELEVATION
# The current elevation values are:
# ['FALSE' 'TRUE' 'UNK' 'unknown']
# ================================
# The new elevation values are:
# ['false' 'true' 'unk' 'unknown']
# | PROCESSING: BIOPSED
# The current biopsed values are:
# ['False' 'True' 'unknown']
# ================================
# The new biopsed values are:
# ['false' 'true' 'unknown']
# | PROCESSING: HAS_PIPED_WATER
# The current has_piped_water values are:
# ['unknown' 'True' 'False']
# ================================
# The new has_piped_water values are:
# ['unknown' 'true' 'false']
# | PROCESSING: HAS_SEWAGE_SYSTEM
# The current has_sewage_system values are:
# ['unknown' 'True' 'False']
# ================================
# The new has_sewage_system values are:
# ['unknown' 'true' 'false']
# | PROCESSING: PESTICIDE
# The current pesticide values are:
# ['unknown' 'False' 'True']
# ================================
# The new pesticide values are:
# ['unknown' 'false' 'true']

# %%
print("The current ethnicity values are: ")
print(df['ethnicity'].unique())

# According to the documentation of the MIDAS dataset, the ethnicity column stands for hispanic or latinos that partied in this survey
# As this does not help us with the prediction of the disease, it introduces significant bias so it will be removed
df = df.drop('ethnicity', axis=1)
df.columns
# Out:
# The current ethnicity values are:
# ['unknown' 'no' 'yes']
# Index(['is_malignant', 'diagnosis', 'dataset_id', 'patient_global', 'img_path',
#        'age', 'sex', 'fitzpatrick', 'lesion_size_mm', 'anatomical_site',
#        'clinical_impression', 'smoking', 'alcohol_consumption',
#        'cancer_history', 'skin_cancer_history', 'background_father',
#        'background_mother', 'bleed', 'hurt', 'itch', 'changed', 'grew',
#        'elevation', 'biopsed', 'diameter_2', 'has_piped_water',
#        'has_sewage_system', 'pesticide', 'clinical_impression_2',
#        'clinical_impression_3', 'race', 'distance', 'is_control',
#        'melanoma_flag', 'pathology_report'],
#       dtype='object')

# %%
print("The current fitzpatrick values are: ")
print(df['fitzpatrick'].unique())
# Out:
# The current fitzpatrick values are:
# ['unknown' '3.0' '1.0' '2.0' '4.0' '5.0' '6.0' 'ii fair skin, blue eyes'
#  'i pale white skin, blue/green eyes, blond/red hair'
#  'iii darker white skin' 'iv light brown skin' 'v brown skin'
#  'vi dark brown or black skin']

# %%
# I have decided to standardize the fitzpatrick values with 1,6 values and 0 for the cases that we do not have a value

fitzpatrick_map = {
    'i pale white skin, blue/green eyes, blond/red hair': 1,
    'ii fair skin, blue eyes': 2,
    'iii darker white skin': 3,
    'iv light brown skin': 4,
    'v brown skin': 5,
    'vi dark brown or black skin': 6,
    'unknown': 0 
}
df['fitzpatrick'] = df['fitzpatrick'].replace(fitzpatrick_map)
df['fitzpatrick'] = pd.to_numeric(df['fitzpatrick'])
df['fitzpatrick'].unique()
# Out:
# array([0., 3., 1., 2., 4., 5., 6.])

# %%
# I need to convert these columns to integers so
df['fitzpatrick'] = df['fitzpatrick'].astype(int)
print("The new fitzpatrick values are: ",df['fitzpatrick'].unique())
# Out:
# The new fitzpatrick values are:  [0 3 1 2 4 5 6]

# %%
print("The current lesion size values in mm are: ")
print(df['lesion_size_mm'].unique())
# The current values are consistent so no need for change yet
# Out:
# The current lesion size values in mm are:
# [ -1.     6.     5.    15.     9.    20.    14.    13.     3.     7.
#   10.     8.    11.     4.    40.    18.    32.    23.    16.    12.
#   30.    19.     2.    17.    22.    24.    31.    35.    25.    21.
#    0.    60.     1.     1.2   89.    26.    42.    29.    90.   100.
#   70.    45.    50.     6.5    5.5    4.5    7.5    1.5    3.25  11.5
#    8.5    9.5   22.5    3.5   10.5    2.5   12.5   15.5   13.5    6.25
#   18.5    4.75  17.5   16.5   80.    26.5    5.25  42.5   55.    32.5
#    8.25   1.15   0.75  33.5    5.75  14.5    4.25   3.75]

# %%
print("The current anatomical site values are: ")
print(df['anatomical_site'].unique())
# Out:
# The current anatomical site values are:
# ['ARM' 'NECK' 'FACE' 'HAND' 'FOREARM' 'CHEST' 'NOSE' 'THIGH' 'SCALP' 'EAR'
#  'BACK' 'FOOT' 'ABDOMEN' 'LIP' 'chest' 'l lower back' 'left upper buttock'
#  'right upper eyelid' 'left forearm' 'left upper back' 'r forehead'
#  'r dorsal hand\xa0' 'nasal bridge' 'l dorsal hand\xa0'
#  'r posterior shoulder' 'r flank\xa0' 'forehead' 'l ear' 'l cheek'
#  'r upper back\xa0' 'l medial ankle' 'l forearm' 'l forehead'
#  'r post auricular scalp' 'mid scalp' 'posterior midline neck'
#  'r distal lateral upper arm\xa0' 'l proximal dorsal forearm\xa0'
#  'r upper back' 'r chest' 'l lateral neck' 'l upper back\xa0'
#  'r upper arm\xa0' 'l posterior neck\xa0' 'r upper arm'
#  'r posterior helix' 'l upper back' 'umbilicus' 'r nasal ala'
#  'l antihelix' 'r elbow' 'l lateral thigh' 'l nasal ala'
#  'r medial forearm' 'mid back' 'r mid back' 'l flank' 'chin' 'l elbow'
#  'right posterior calf' 'l dorsal 2nd toe' 'l chest' 'r dorsal foot\xa0'
#  'r abdomen\xa0' 'r posterior calf' 'right posterior calf\xa0'
#  'left lower back' 'left posterior neck' 'left anterior thigh\xa0'
#  'l medial thigh' 'r thigh' 'r upper shoulder' 'l shoulder' 'r shoulder'
#  'r lateral calf\xa0' 'l lateral calf\xa0' 'r index finger'
#  'l upper chest' 'r upper chest' 'r lower eyelid' 'mid chest'
#  'r lateral neck' 'posterior neck' 'frontal scalp' 'r medial thigh'
#  'l upper arm\xa0' 'r preauricular\xa0' 'l thigh' 'r 4th dorsal toe'
#  'l posterior helix' 'l chest\xa0' 'l mandible' 'nasal tip'
#  'lower mid back' 'l lateral calf' 'right post calf' 'r nasal sidewall'
#  'r upper post calf' 'l neck\xa0' 'left chest' 'r forearm'
#  'r medial cheek' 'mid lower back' 'r lower back\xa0' 'l lower abdomen'
#  'l anterior neck' 'r medial shin' 'r posterior arm' 'r axilla'
#  'mid upper back' 'l forearm\xa0' 'central chest' 'right upper back'
#  'left upper arm' 'r clavicle' 'mid low back' 'r back' 'r posterior thigh'
#  'leg' 'r shin' 'right frontal scalp' 'right posterior helix'
#  'right chest' 'r cheek' 'left shin' 'l back' 'l anterior lower leg'
#  'left shoulder lateral' 'l mid back' 'r preauricular' 'mid abdomen'
#  'l ribcage' 'neck' 'l foot' 'r back\xa0' 'l chest medial'
#  'l chest lateral' 'left neck' 'right thigh' 'hypogastric region'
#  'l abdomen' 'left cutaneous lip' 'r leg' 'left calf' 'l calf'
#  'l malar cheek' 'left heel' 'r lower leg' 'r 3rd finger'
#  'right superior helix of ear' 'r lateral calf' 'r posterior neck'
#  'r shoulder\xa0'
#  'l upper back (this is mislabeled on epic as r upper back)' 'l upper arm'
#  'left lobule of ear' 'r calf' 'l nasal bridge' 'r medial lower eyelid'
#  'l temple' 'l postauricular' 'r temple' 'r deltoid' 'right shin\xa0'
#  'low back' 'l lower lip' 'left lower vermilion border of lip' 'abdomen'
#  'r lateral leg' 'r dorsal hand' 'left posterior shoulder'
#  'r medial cheek\xa0' 'left temple' 'l crown of scalp' 'r frontal scalp'
#  'back' 'r popliteal fossa' 'left forearm\xa0' 'r thigh\xa0'
#  'crown of scalp' 'right shoulder' 'left abdomen' 'l shin'
#  'r retro auricular\xa0' 'l deltoid' 'r neck' 'l upper abdomen\xa0'
#  'right anterior shin' 'left upper lip' 'nasal dorsum' 'r foot\xa0'
#  'l nasal tip' 'l nose' 'left cheek' 'shoulder' 'r abdomen' 'l breast'
#  'r lower lateral leg' 'l popliteal' 'l upper calf' 'l lower calf'
#  'r flank' 'r deltoid\xa0' 'r lower cheek' 'central lower back' 'r arm'
#  'central upper back\xa0' 'right lower back' 'l melolabia fold\xa0'
#  'l lateral cheek\xa0' 'l lower medial cheek\xa0' 'left back'
#  'l lateral cheek' 'posterior neck\xa0' 'right forearm' 'left 4th finger'
#  'right crown of scalp' 'right anterior upper arm\xa0'
#  'upper mid back\xa0' 'right upper back\xa0' 'r antihelix'
#  'left posterior calf' 'right neck' 'superior l upper back' 'upper chest'
#  'r posterior shoulder\xa0' 'r sideburn' 'right medial arm\xa0' 'r4 digit'
#  'right leg' 'right back' 'left postauricular' 'r cheek\xa0' 'l neck'
#  'left back\xa0' 'left dorsal foot' 'right cheek' 'right helix'
#  'mid nasal dorsum\xa0' 'r lower leg\xa0' 'right flank' 'l temple\xa0'
#  'l parietal scalp\xa0' 'upper mid r chest\xa0' 'l abdomen\xa0'
#  '\xa0l anterior shin\xa0' 'right clavicle\xa0' 'left shoulder'
#  'left lower leg' 'right cheek\xa0' 'right calf' 'left mid back'
#  'right lateral neck\xa0' 'nose' 'left anterior thigh'
#  'left upper back\xa0' 'left lateral cheek' 'crown of scalp\xa0'
#  'upper middle lip\xa0' 'l shoulder\xa0' 'l lower leg\xa0'
#  'left cheek\xa0' 'central chest\xa0' 'right mid back\xa0'
#  'left dorsal hand' 'left chest\xa0' 'l arm\xa0' 'left thigh'
#  'r clavicle\xa0' 'l preauricular\xa0' 'l cheek\xa0' 'l shin\xa0'
#  'r low chest' 'l knee' 'left anterior shin\xa0' 'right forearm\xa0'
#  'right lateral lower leg\xa0' 'r lower leg inferior' 'right elbow\xa0'
#  'nasal bridge\xa0' 'left upper arm\xa0' 'l lower back\xa0'
#  'l medial cheek\xa0' 'l forehead\xa0' 'r vertex scalp\xa0'
#  'r forearm\xa0' 'l infra-auricular' 'r superior helix' 'r lateral knee'
#  'l lateral neck\xa0' 'r infirmary breast' 'r lateral neck\xa0'
#  'l mid back\xa0' 'left alar crease of nose' 'right nasal sidewall\xa0'
#  'right nasal supra tip' 'right nasal tip' 'left ear' 'left helix'
#  'left frontal scalp' 'right inguinal fold' 'right dorsal hand'
#  'right temple\xa0' 'left posterior helix' 'left shin\xa0' 'left buttock'
#  'mid abdomen\xa0' 'left anterior lower leg' 'right medial lower leg'
#  'right plantar arch' 'r mid vertex' 'mid back\xa0' 'right superior helix'
#  'right lower leg' 'right calf\xa0' 'mid central back' 'left central back'
#  'upper back' 'l wrist' 'right chin' 'right pre-auricular'
#  'left postauricular area' 'r dorsal foot' 'scalp' 'l alar crease'
#  'philtrum' 'right 3rd intertarsal region' 'r elbow joint' 'lower back'
#  'l arm' 'l root of neck\xa0' 'r upper abdomen' 'left upper thigh'
#  'rt superior parietal' 'rt inferior parietal' 'l posterior shoulder'
#  'right forehead' 'l medial shin' 'l leg' 'l clavicle' 'l lower leg'
#  'r jaw' 'r lower back' 'r lateral back' 'left mid distal dorsal foot'
#  'r frontal hairline' 'right postauricular' 'l axilla'
#  'l superior helix of ear' 'left nasal ala' 'left forehead'
#  'left vertex scalp' 'left alar crease (peri-nasal)'
#  'right lateral mid back' 'l medial calf' 'r preauricular cheek'
#  'left jawline' 'right anterior scalp' 'submental jaw'
#  'right nasal sidewall' 'r proximal leg melanoma scar' 'arm'
#  'left upper cutaneous lip' 'l dorsal forearm' 'l hip' 'lower abdomen'
#  'r lateral cheek' 'mid vertex scalp' 'left pre-auricular'
#  'r vertex scalp' 'right abdomen' 'central upper back' 'l hand'
#  'right lower eyelid' 'r medial chest' 'l inner upper arm'
#  'right lateral ankle' 'low mid back' 'mid forehead' 'left arm medial'
#  'left arm lateral' 'l frontal scalp' 'mid nasal dorsum' 'left eyebrow'
#  'right buttock' 'mid upper cutaneous lip' 'mid nasal supra tip'
#  'mid posterior neck' 'left post auricular' 'right jaw' 'right ankle'
#  'left lower flank' 'left groin' 'r lower chest' 'right hand'
#  'r nasal fold' 'l upper vermilion border' 'left clavicle'
#  'left anterior shoulder' 'l medial cheek' 'right medial cheek'
#  'right temple' 'mid nasal supratip' 'left knee' 'right medial knee'
#  'left lateral neck' 'r side burn' 'left thigh distal'
#  'left thigh proximal' 'mid vertex' 'r conchal bowl' 'right lateral cheek'
#  'upper mid abdomen' 'supra pubic skin' 'left shoulder anterior'
#  'left shoulder posterior' 'left infra mammary' 'right lateral thigh'
#  'right anterior leg' 'l preauricular' 'right arm' 'left nasal dorsum'
#  'left scalp vertex' 'right vertex scalp' 'right lateral canthus'
#  'mid-nasal dorsum' 'right nasal ala' 'right clavicle'
#  'l medial plantar heel' 'left mid plantar heel' 'cheek' 'r base of neck'
#  'left arm' 'mons pubis' 'l suprapubic' 'central upper abdomen'
#  'l nasal supratip' 'right upper arm' 'left elbow' 'left nasal supratip'
#  'lower lip' 'right elbow' 'right mid back' 'left lower cutaneous lip'
#  'right distal forearm' 'right proximal forearm'
#  'right superior upper arm' 'left lateral jawline' 'l nasal sidewall'
#  'left scapula' 'right upper abdomen' 'r thumb base' 'l inguinal crease'
#  'l flank superior' 'l flank inferior' 'thigh' 'left leg'
#  'l middle finger' 'lower vermilion lip' 'right posterior thigh'
#  'left posterior thigh' 'l posterior calf' 'right ear' 'left nasal bridge'
#  'r nose tip' 'right superomedial thigh' 'right buttox' 'right knee'
#  'left breast' 'r lateral eyelid' 'r upper eyelid' 'l eyebrow' 'l helix'
#  'right mid-back' 'l posterior ankle' 'l dorsal foot' 'left inner thigh'
#  'r crown of scalp' 'l hand radial' 'l hand ulnar' 'r heel'
#  'left mid thigh' 'r lateral foot' 'r eyelid' 'mid l vertex scalp'
#  'l dorsal hand' 'l superior helix' 'l inferior upper arm'
#  'l lateral knee' 'r nasal bridge' 'r upper lip' 'l ear scapha'
#  'l jawline' 'l lower eyelid' 'right shin' 'l anterior thigh'
#  'r nasal supratip' 'l medial eyebrow' 'r medial malleolus' 'r antitragus'
#  'r pinky' 'l 5th finger' 'l 2nd finger' 'r eyebrow' 'l inframammary'
#  'l jaw' 'l occiput']

# %%
# Due to the size and difference of all the values the data should first be cleaned
df['anatomical_site_clean'] = df['anatomical_site'].str.lower()
df['anatomical_site_clean'] = df['anatomical_site_clean'].str.replace(r'[\xa0]', '', regex=True)
df['anatomical_site_clean'] = df['anatomical_site_clean'].str.strip()

# And then be split into smaller sets
body_region_map = {
    'head_neck': ['face', 'ear', 'nose', 'lip', 'cheek', 'scalp', 'neck', 'forehead', 'jaw', 'temple', 'chin', 'eyelid', 'eyebrow', 'preauricular', 'postauricular', 'malar', 'occiput'],
    'trunk': ['chest', 'back', 'abdomen', 'flank', 'shoulder', 'axilla', 'ribcage', 'breast', 'clavicle', 'umbilicus', 'groin', 'inguinal', 'suprapubic'],
    'upper_extremity': ['arm', 'forearm', 'hand', 'elbow', 'wrist', 'finger', 'deltoid', 'thumb'],
    'lower_extremity': ['thigh', 'leg', 'foot', 'calf', 'shin', 'knee', 'ankle', 'toe', 'heel', 'popliteal', 'buttock'],
    'unknown': ['unknown'] 
}
def map_to_region(site):
    """Maps a clean anatomical site string to one of the major body regions."""
    if pd.isna(site) or site == '':
        return 'unknown'

    for region, keywords in body_region_map.items():
        for keyword in keywords:
            if keyword in site:
                return region
    # If no keyword is found
    return 'other_unmapped' 

# Apply the mapping function to the cleaned column
df['anatomical_site'] = df['anatomical_site_clean'].apply(map_to_region)

# %%
# The reason that the data was split into 5 sets was to reduce the variance and the risk of overfitting the model, as the amount of data is relatively small 
print("The current anatomical site values are: ")
print(df['anatomical_site'].unique())
# Out:
# The current anatomical site values are:
# ['upper_extremity' 'head_neck' 'trunk' 'lower_extremity' 'other_unmapped']

# %%
print("The current clinical impression values are: ")
print(df['clinical_impression'].unique())
# As we know, we have three clinical impression columns so we need to create a method to clean all three since they use the same values
# Out:
# The current clinical impression values are:
# ['unknown' '7-malignant-bcc' '1-benign-melanocytic nevus' '6-benign-other'
#  '14-other-non-neoplastic/inflammatory/infectious' '8-malignant-scc'
#  '9-malignant-sccis' '10-malignant-ak' '3-benign-fibrous papule'
#  '4-benign-dermatofibroma' '2-benign-seborrheic keratosis'
#  '5-benign-hemangioma' '11-malignant-melanoma'
#  '13-other-melanocytic lesion with possible re-excision (severe/spitz nevus, aimp)'
#  '12-malignant-other']

# %%
impression_mapping = {
    # Target: nevus
    'benign-melanocytic nevus': 'nevus',
    'other-melanocytic lesion with possible re-excision (severe/spitz nevus, aimp)': 'nevus',
    
    # Target: benign_other
    'benign-fibrous papule': 'benign_other',
    'benign-dermatofibroma': 'benign_other',
    'benign-hemangioma': 'benign_other',
    'benign-other': 'benign_other', 
    
    # Target: seborrheic_keratosis
    'benign-seborrheic keratosis': 'seborrheic_keratosis',
    
    # Target: bcc
    'malignant-bcc': 'bcc',
    
    # Target: scc
    'malignant-scc': 'scc',
    'malignant-sccis': 'scc',
    
    # Target: melanoma
    'malignant-melanoma': 'melanoma',
    
    # Target: ak (Actinic Keratosis)
    'malignant-ak': 'ak',
    
    # Target: other_malignant
    'malignant-other': 'other_malignant',
    
    # Target: other_unclassified (for unknowns and non-neoplastic)
    'unknown': 'other_unclassified',
    'other-non-neoplastic/inflammatory/infectious': 'other_unclassified',
}

# The following function will clean and map the three clinical impression columns
def standardize_impression_column(df, column_name, mapping_dict):
    print(f"\nProcessing and cleaning column: {column_name}")

    # Step 1: Preliminary Cleaning and Splitting
    clean_col = df[column_name].astype(str).str.lower().str.strip()
    split_temp = clean_col.str.split('-', n=1, expand=True)
    
    # Step 2: Extract the Descriptive Impression Name
    mask_no_hyphen = split_temp[1].isnull()
    impression_name = np.where(mask_no_hyphen, split_temp[0], split_temp[1])
    
    # Step 3: Define the new column name (e.g., diag_group, diag_2_group)
    new_group_name = column_name.replace('clinical_impression', 'cli_impres').replace('cli_impres', 'cli_impres_') + '_group'
    
    # Step 4: Apply the Mapping
    # Fill any unmapped values with 'other_unclassified'
    df[new_group_name] = pd.Series(impression_name).map(mapping_dict).fillna('other_unclassified')
    
    print(f"-> Created new categorical column: {new_group_name}")
    print(f"-> Value Counts for {column_name}:\n{df[new_group_name].value_counts().to_string()}")
    
    return df    


# List of columns to process
impression_columns = ['clinical_impression', 'clinical_impression_2', 'clinical_impression_3']

# To map each column sequentially
for col in impression_columns:
    df = standardize_impression_column(df, col, impression_mapping)
# Out:
# Processing and cleaning column: clinical_impression
# -> Created new categorical column: cli_impres__group
# -> Value Counts for clinical_impression:
# cli_impres__group
# other_unclassified      2402
# nevus                    967
# bcc                      689
# benign_other             473
# seborrheic_keratosis     454
# scc                      348
# melanoma                 165
# ak                       152
# other_malignant            9
#
# Processing and cleaning column: clinical_impression_2
# -> Created new categorical column: cli_impres__2_group
# -> Value Counts for clinical_impression_2:
# cli_impres__2_group
# other_unclassified      2830
# nevus                    664
# scc                      576
# benign_other             496
# melanoma                 460
# seborrheic_keratosis     258
# ak                       184
# bcc                      179
# other_malignant           12
#
# Processing and cleaning column: clinical_impression_3
# -> Created new categorical column: cli_impres__3_group
# -> Value Counts for clinical_impression_3:
# cli_impres__3_group
# other_unclassified      3606
# melanoma                 525
# scc                      450
# nevus                    294
# benign_other             260
# seborrheic_keratosis     177
# bcc                      164
# ak                       148
# other_malignant           35

# %%
print("The current diameter values are: ")
print(df['diameter_2'].unique())
# The current values are consistent so no need for change yet
# Out:
# The current diameter values in mm are:
# [-1.   5.  10.   7.   4.  18.  12.  13.   3.   8.   9.   6.  11.  20.
#  15.  24.   2.  14.  21.  16.  25.   1.   0.  33.  40.  23.  17.  27.
#  22.  30.   1.2 26.  34.  19.  70.  60.  28.  32.  48. ]

# %%
print("The current race values are: ")
print(df['race'].unique())
# The current values are consistent so no need for change yet
# Out:
# The current race values are:
# ['unknown' 'white' 'asian' 'other' 'black or african american'
#  'american indian or alaska native']

# %%
# Below, we can see depicted the size of each race
df['race'].value_counts()
# Out:
# race
# white                               2890
# unknown                             2401
# asian                                171
# other                                163
# black or african american             27
# american indian or alaska native       7
# Name: count, dtype: int64

# %%
# We are combining other, african american and american indian into one due to the lack of size
race_mapping = {
    'white': 'white',
    'unknown': 'unknown',
    'asian': 'asian',
    'other': 'other_minority',
    'black or african american': 'other_minority',
    'american indian or alaska native': 'other_minority'
}
df['race_group'] = df['race'].map(race_mapping).fillna('other_minority')
df['race_group'].value_counts()
# Out:
# race_group
# white             2890
# unknown           2401
# other_minority     197
# asian              171
# Name: count, dtype: int64

# %%
print("The current distance values are: ")
print(df['distance'].unique())
# To clean this we will convert feet to inches, assume dscope to 1 inch and the rest will be negative values
# Out:
# The current distance values are:
# ['-1' '1ft' '6in' 'dscope' 'n/a - virtual']

# %%
distance_mapping = {
    '1ft': 12,
    '6in': 6,
    'dscope': 1,
    # '-1': NaN,
    # 'n/a - virtual': NaN,
}
df['distance_group'] = df['distance'].map(distance_mapping)
print(df['distance_group'].unique())
# Out:
# [nan 12.  6.  1.]

# %%
print("The current is control values are: ")
print(df['is_control'].unique())
# Out:
# The current is control values are:
# ['unknown' 'no' 'yes']

# %%
print("The current melanoma flag values are: ")
print(df['melanoma_flag'].unique())
# Out:
# The current melanoma flag values are:
# ['unknown' 'no' 'yes']

# %%
print("The current pathology report values are: ")
print(df['pathology_report'].unique())
# Out:
# The current pathology report values are:
# ['unknown'
#  'focal squamous cell carcinoma, in situ, \xa0 arising in background actinic keratosis\xa0'
#  'intradermal melanocytic nevus, transected at the deep margin\xa0'
#  'findings consistent with ruptured \xa0 follicle/epidermal cyst\xa0'
#  'well-differentiated invasive squamous cell \xa0 carcinoma'
#  'actinic keratosis' 'seborrheic keratosis'
#  'basal cell carcinoma, superficial type, transected at the peripheral margin'
#  'invasive squamous cell carcinoma\xa0'
#  'basal cell carcinoma, infiltrative type\xa0'
#  '\xa0at least squamous cell carcinoma, in-situ, \xa0 transected at all margins \xa0 \xa0 incidental intradermal melanocytic nevus, \xa0 transected at all margins\xa0'
#  'invasive squamous cell carcinoma, excised\xa0'
#  'traumatized seborrheic keratosis\xa0'
#  'hyperplastic actinic keratosis\xa0'
#  '\xa0basal cell carcinoma, nodular type, \xa0 transected at the deep margin\xa0'
#  'superficial invasive squamous cell carcinoma'
#  'moderately differentiated invasive squamous cell carcinoma'
#  'basal cell carcinoma, superficial and nodular \xa0 type, transected at all margins'
#  'focal squamous cell carcinoma, in-situ, \xa0 excised;hypertrophic actinic keratosis, transected at the peripheral margin\xa0'
#  'at least squamous cell carcinoma, in-situ, \xa0 transected at the deep margin\xa0'
#  'superficially invasive squamous cell \xa0 carcinoma, transected at the deep margin'
#  '\xa0invasive squamous cell carcinoma'
#  'at least squamous cell carcinoma, in-situ, transected at all margins (see comment)'
#  '\xa0basal cell carcinoma, nodular and \xa0 infiltrative type\xa0'
#  'epidermal acanthosis and hyerkeratosis'
#  'basal cell carcinoma, nodular type\xa0'
#  'invasive squamous cell carcinoma'
#  'epidermal acanthosis and hyperkeratosis\xa0'
#  'dermal neutrophilic abscess with \xa0 gram-positive bacterial cocci'
#  'basaloid proliferation, favor basal cell carcinoma, nodular type\xa0'
#  'squamous cell carcinoma, in situ\xa0'
#  '\xa0basal cell carcinoma, nodular type\xa0 \xa0'
#  'dysplastic junctional melanocytic nevus with \xa0 persistent/recurrent features, excised\xa0 \xa0\xa0 \xa0 \xa0 \xa0 \xa0 -- \xa0 \xa0 \xa0 \xa0 \xa0underlying dermal scar\xa0'
#  'verruca vulgaris' 'mildly dysplastic compound melanocytic nevus'
#  'mild compound melanocytic nevus, focally \xa0 transected at the peripheral margin'
#  'verruca vulgaris\xa0'
#  'compound melanocytic nevus, transected at the peripheral margin\xa0'
#  'compound melanocytic nevus, transected at all \xa0 margins\xa0'
#  '\xa0basal cell carcinoma, superficial and nodular type, transected at the peripheral margin\xa0'
#  'basal cell carcinoma, superficial type\xa0'
#  'basal cell carcinoma, nodular type'
#  'actinic keratosis with adjacent seborrheic \xa0 keratosis\xa0'
#  '\xa0well-differentiated squamous cell carcinoma, \xa0 keratoacanthoma type, transected at all margins\xa0'
#  'traumatized intradermal melanocytic nevus, transected at the deep margin\xa0'
#  'basal cell carcinoma, superficial type, \xa0 transected at the deep margin\xa0'
#  '\xa0basal cell carcinoma, nodular type, \xa0 transected at all margins\xa0'
#  '\xa0well-differentiated squamous cell carcinoma, \xa0 keratoacanthoma type, transected at the deep margin\xa0'
#  '\xa0verruca vulgaris\xa0' 'seborrheic keratosis\xa0'
#  'epidermal inclusion cyst'
#  'basal cell carcinoma, superficial and nodular type'
#  '\xa0basal cell carcinoma, superficial type\xa0'
#  'basal cell carcinoma, superficial and nodular \xa0 type\xa0'
#  '\xa0basal cell carcinoma, nodular type\xa0'
#  'atypical lymphoid infiltrate\xa0'
#  'severely atypical compound melanocytic nevus'
#  '\xa0seborrheic keratosis\xa0'
#  '\xa0well-differentiated squamous cell carcinoma, keratoacanthoma type\xa0'
#  'compound melanocytic nevus with special site atypia, transected at the deep margin'
#  'inflamed and traumatized seborrheic keratosis' 'prurigo nodularis'
#  'actinic keratosis\xa0' 'macular seborrheic keratosis'
#  'pigmented basal cell carcinoma, nodular type\xa0' 'porokeratosis'
#  'eccrine poroma' 'compound melanocytic nevus, excised on plane\xa0'
#  'squamous cell carcinoma, in-situ with clear \xa0 cell features, transected at all margins\xa0'
#  'basal cell carcinoma, superficial type, \xa0 transected at the peripheral margin\xa0'
#  'basal cell carcinoma, nodular and \xa0 infiltrative type\xa0'
#  'squamous cell carcinoma, in-situ' 'squamous cell carcinoma, in-situ\xa0'
#  'basal cell carcinoma, superficial type'
#  'combined conventional (nevocellular) and deep penetrating nevus, focally transected at the deep margin'
#  'compound melanocytic nevus, excised on plane of section reviewed\xa0'
#  'invasive melanoma'
#  'atypical compound melanocytic proliferation, \xa0 favor severely dysplastic compound melanocytic nevus with florid \xa0 fibroplasia, excised (see comment)'
#  'severely dysplastic compound melanocytic \xa0 nevus, excised (see comment)'
#  'mildly dysplastic compound melanocytic nevus, excised'
#  'moderately dysplastic compound melanocytic nevus, excised on plane of section reviewed\xa0'
#  'cellular blue nevus, excised on plane of \xa0 section'
#  '\xa0severely dysplastic junctional melanocytic \xa0 nevus, excised on plane of section reviewed'
#  'malignant melanoma in situ, superficial type, \xa0 excised on plane of section reviewed\xa0'
#  '\xa0inflamed pigmented actinic keratosis\xa0'
#  '\xa0basal cell carcinoma, nodular and \xa0 infiltrative type \xa0 \xa0\xa0 \xa0 \xa0 \xa0 \xa0 -- \xa0 \xa0 \xa0 \xa0 \xa0focal findings consistent with ruptured \xa0 follicle/epidermal cyst\xa0'
#  'moderately dysplastic junctional melanocytic \xa0 nevus, narrowly excised on plane of sections examined\xa0'
#  'macular seborrheic keratosis\xa0'
#  '\xa0surface of well-differentiated squamous cell carcinoma, keratoacanthoma type\xa0'
#  'traumatized sebaceous hyperplasia and \xa0 adjacent folliculitis\xa0'
#  '\xa0lichenoid actinic keratosis'
#  'basal cell carcinoma, nodular type, transected at all margins\xa0'
#  'moderately differentiated invasive squamous cell carcinoma, transected at all margins'
#  'basal cell carcinoma, superficial and nodular type, transected at the peripheral margin'
#  '\xa0lichenoid keratosis\xa0' '\xa0squamous cell carcinoma, in situ\xa0'
#  'inflamed actinic keratosis\xa0 \xa0'
#  'superficial dermal vascular ectasia\xa0'
#  'mildly dysplastic compound melanocytic nevus, transected at the peripheral margin\xa0'
#  'mildly dysplastic compound melanocytic nevus, excised on plane of section reviewed'
#  'lentiginous junctional melanocytic nevus'
#  'pigmented seborrheic keratosis'
#  'melanoma in situ, superficial spreading type, excised on plane of section reviewed (see comment)'
#  'poroma, transected at all margins\xa0'
#  'atypical junctional melanocytic proliferation'
#  'malignant melanoma in-situ, superficial \xa0 spreading type, transected at the peripheral margin'
#  'compound melanocytic nevus, narrowly excised on plane of section reviewed\xa0'
#  'mildly dysplastic compound melanocytic nevus, \xa0 focally transected at the peripheral margin'
#  'moderately dysplastic compound melanocytic \xa0 nevus, excised on plane of section reviewed\xa0'
#  '\xa0solar lentigo \xa0 adjacent macular seborrheic keratosis\xa0'
#  '\xa0malignant melanoma in-situ, superficial \xa0 spreading type, narrowly excised\xa0'
#  'malignant melanoma in-situ, superficial spreading type, transected at the peripheral margin (see comment)'
#  'invasive melanoma, superficial spreading \xa0 type'
#  'blue nevus, transected at the deep margin\xa0'
#  '\xa0mildly dysplastic compound melanocytic nevus'
#  'basal cell carcinoma, superficial type, \xa0 transected at all margins\xa0'
#  'compound melanocytic nevus' 'squamous cell carcinoma, in situ'
#  'favor surface of traumatized angioma'
#  'compound melanocytic nevus, excised\xa0'
#  'compound melanocytic nevus, excised'
#  'invasive melanoma, superficial spreading type'
#  'basal cell carcinoma, nodular type\xa0 \xa0'
#  'favor surface of actinic keratosis\xa0'
#  'solar lentigo with dermal hemorrhage\xa0'
#  '\xa0-- irritated seborrheic keratosis\xa0 -- adjacent actinic keratosis'
#  'invasive melanoma, mixed lentigo maligna and desmoplastic types'
#  'solar lentigo\xa0' 'intradermal melanocytic nevus'
#  'atypical acral junctional melanocytic \xa0 proliferation, favor acral melanoma in situ, excised on plane of section reviewed'
#  '\xa0squamous cell carcinoma, in situ'
#  'melanoma in situ, superficial spreading type, excised on plane of section examined; with adjacent mildly dysplastic compound melanocytic nevus, excised on plane of section reviewed'
#  '\xa0at least squamous cell carcinoma, in situ'
#  'pigmented basal cell carcinoma, nodular type'
#  'mildly dysplastic junctional melanocytic \xa0 nevus'
#  '\xa0inflamed clonal seborrheic keratosis'
#  'moderately dysplastic compound melanocytic nevus'
#  'squamous cell carcinoma, in situ with ulceration and marked inflammation'
#  '\xa0solar lentigo\xa0'
#  '\xa0epidermal hyperplasia and stasis dermatitis\xa0'
#  'vellus hair cyst\xa0'
#  'basal cell carcinoma, nodular type, \xa0 transected at the deep margin'
#  'basal cell carcinoma, micronodular type, \xa0 transected at the deep margin\xa0'
#  'inflamed compound melanocytic nevus'
#  'inflamed and partially regressed atypical junctional melanocytic nevus'
#  'intradermal melanocytic nevus, transected at all margins\xa0'
#  'pigmented seborrheic keratosis\xa0'
#  'superficially invasive squamous cell \xa0 carcinoma\xa0'
#  '\xa0inflamed actinic keratosis\xa0'
#  '\xa0basal cell carcinoma, nodular type'
#  'atypical squamous proliferation, favor \xa0 invasive squamous cell carcinoma, excised on plane of section examined \xa0'
#  '\xa0malignant melanoma in-situ, superficial \xa0 spreading type, transected at the peripheral margin'
#  'mild epithelial acanthosis, hyperkeratosis, and parakeratosis (see comment)'
#  'squamous cell carcinoma in situ\xa0'
#  'inflamed, moderately atypical compound \xa0 melanocytic nevus, focally transected at the peripheral margin'
#  'basal cell carcinoma, superficial and nodular'
#  'lobular capillary hemangioma'
#  'basal cell carcinoma, nodular type, \xa0 transected at all margins'
#  'squamous cell carcinoma, keratoacanthoma type, transected \xa0 at all margins\xa0'
#  'verrucous keratosis\xa0' 'residual basal cell carcinoma, excised\xa0'
#  'mildly dysplastic compound melanocytic nevus, excised on plane of section reviewed\xa0'
#  'dermatofibroma\xa0' 'malignant melanoma in situ, lentigo'
#  'severely dysplastic compound melanocytic nevus with focal regression, excised on plane of section examined\xa0'
#  'lentiginous junctional melanocytic nevus, excised on plane of section examined'
#  'mildly dysplastic junctional melanocytic nevus, excised on plane of section reviewed'
#  'well-differentiated squamous cell carcinoma, keratoacanthoma type\xa0'
#  'squamous cell carcinoma, in-situ, transected at all margins\xa0'
#  'dense lymphohistiocytic inflammation with associated capillaries, compatible with residual inflamed hemangioma'
#  'pigmented actinic keratosis'
#  'mildly dysplastic junctional melanocytic \xa0 nevus, excised on plane of section reviewed'
#  'inflamed compound melanocytic nevus with severe atypia, excised on plane of section reviewed'
#  'myxoid pleomorphic fibroma' 'inverted follicular keratosis' 'scar'
#  'focal squamous cell carcinoma, in-situ, \xa0 transected at the peripheral margin\xa0'
#  'mildly dysplastic junctional melanocytic \xa0 nevus, excised\xa0'
#  'pigmented basal cell carcinoma, nodular type, transected at the deep margin'
#  'sebaceous hyperplasia and dermal scar\xa0' 'solar lentigo'
#  'invasive melanoma, superficial spreading type\xa0' 'neurofibroma\xa0'
#  'pilar leiomyoma\xa0' 'basal cell carcinoma, nodular type, excised\xa0'
#  'severely atypical combined melanocytic nevus, transected across the deep margin\xa0'
#  'actinic keratosis, transected at the peripheral margin'
#  'lichenoid keratosis\xa0'
#  '\xa0basal cell carcinoma, superficial type, \xa0 excised on plane of section reviewed'
#  'mildly dysplastic compound melanocytic nevus, \xa0 excised on plane of section reviewed'
#  "lichenoid actinic keratosis and\xa0adjacent suprabasilar acantholysis, \xa0 consistent with grover's disease\xa0"
#  'severely dysplastic compound melanocytic nevus, transected at the peripheral margin'
#  'ulcerated actinic keratosis\xa0' 'focal dermal scar'
#  'follicular cyst (infundibular type)' 'surface of basaloid carcinoma\xa0'
#  'atypical compound melanocytic proliferation, transected at the peripheral margin'
#  'hyperplastic actinic keratosis with adnexal extension'
#  'hyperplastic actinic keratosis' 'dermal scar'
#  '\xa0basal cell carcinoma, superficial type, \xa0 transected at the peripheral margin'
#  'ruptured follicle/epidermal cyst'
#  'folliculitis with associated cutaneous \xa0 lymphoid hyperplasia\xa0'
#  'melanoma in situ arising in association with a compound melanocytic nevus, transected at the deep margin (see comment)'
#  'basal cell carcinoma, superficial type, \xa0 focally transected at the peripheral margin'
#  'basal cell carcinoma, nodular and infiltrative type, narrowly excised'
#  'basal cell carcinoma, nodular type, transected at the deep margin'
#  'basal cell carcinoma, nodular type, transected at all margins'
#  'basal cell carcinoma' 'dermatofibroma'
#  'inflamed and moderately dysplastic compound melanocytic nevus, excised on plane of section reviewed\xa0'
#  'compound melanocytic nevus, transected at the \xa0 deep margin\xa0'
#  'invasive melanoma, superficial spreading (see comment) \xa0 \xa0\xa0 \xa0 \xa0-- \xa0invasive component excised on plane of section reviewed \xa0 \xa0\xa0 \xa0 -- \xa0 in situ component transected at the peripheral margin \xa0 \xa0\xa0 \xa0 -- \xa0 breslow depth 0.4 mm \xa0 \xa0\xa0 \xa0 -- \xa0 mitotic index: 0/mm2 \xa0 \xa0\xa0 \xa0 -- \xa0 ulceration absent'
#  'compound melanocytic nevus, transected at all margins\xa0'
#  'surface of atypical squamous proliferation'
#  'invasive squamous cell carcinoma, transected at the deep margin\xa0'
#  'lentiginous compound melanocytic nevus, \xa0 excised (see comment)'
#  'folliculitis' 'nevus lipomatosis superficialis'
#  'ulcerated and inflamed actinic keratosis\xa0'
#  'epidermal acanthosis with prominent \xa0 spongiosis and eosinophils\xa0'
#  'moderately dysplastic compound melanocytic nevus, focally transected at the peripheral margin'
#  'malignant melanoma in situ, lentigo maligna type, with regression, excised on plane of section examined\xa0'
#  'mildly dysplastic compound melanocytic \xa0 nevus,narrowly \xa0excised on plane of section reviewed\xa0'
#  'keloid\xa0' 'inflamed keloid'
#  'epidermal acanthosis and spongiosis with \xa0 serum crust and dermal fibrosis\xa0'
#  'lichenoid keratosis'
#  'severely dysplastic compound melanocytic \xa0 nevus, narrowly excised on plane of section reviewed\xa0'
#  'basal cell carcinoma, nodular type, with \xa0 eccrine features\xa0'
#  'macular seborrheic keratosis, focal dermal scar'
#  'mildly dysplastic compound melanocytic nevus, transected at the peripheral margin'
#  '\xa0basal cell carcinoma, superficial and nodular'
#  'intradermal melanocytic nevus, transected at all margins'
#  'compound melanocytic nevus, transected at the deep margin\xa0'
#  'basal cell carcinoma, nodular and \xa0 infiltrative type, transected at all margins'
#  'blue nevus, transected at the deep margin'
#  'epidermal ulceration with acute and chronic inflammation, compatible with erosive pustular dermatosis'
#  'compound melanocytic nevus, focally \xa0 transected at the deep margin\xa0'
#  'inflamed seborrheic keratosis'
#  'compound melanocytic nevus, focally \xa0 transected at the peripheral margin\xa0'
#  'nodular solar elastosis with vascular ectasia and background folliculitis'
#  'poorly differentiated carcinoma, compatible with squamous cell carcinoma\xa0'
#  'epidermal invagination'
#  'inflamed compound melanocytic nevus, excised on plane of section reviewed'
#  'compound melanocytic nevus, transected at the peripheral margin'
#  'findings consistent with ruptured follicle/ epidermal cyst'
#  'malignant melanoma in situ, transected at the peripheral margin\xa0'
#  'invasive melanoma, nodular type\xa0 invasive component excised on plane of section examined\xa0 in situ component excised on plane of section examined\xa0 breslow depth: 4.0mm\xa0 mitotic index: 20/mm2\xa0 ulceration: present'
#  '\xa0basal cell carcinoma, superficial type'
#  'basal cell carcinoma, superficial type\xa0 \xa0'
#  'basal cell carcinoma, superficial and nodular types\xa0'
#  'moderately dysplastic junctional melanocytic nevus, excised on plane of section reviewed'
#  'basal cell carcinoma, superficial and nodular type, excised on plane of section reviewed\xa0'
#  'seborrheic keratosis \xa0 \xa0\xa0 \xa0 -- \xa0 adjacent actinic keratosis'
#  'squamous cell carcinoma, in-situ, transected at the peripheral margin\xa0'
#  'eroded actinic keratosis'
#  'mildly dysplastic junctional melanocytic \xa0 nevus, excised on plane of section reviewed\xa0'
#  'actinic keratosis \xa0 \xa0\xa0 \xa0 \xa0 \xa0 \xa0 -- \xa0 \xa0 \xa0 \xa0 \xa0adjacent seborrheic keratosis'
#  'inflamed seborrheic keratosis\xa0'
#  'actinic keratosis with underlying dermal scar'
#  'basal cell carcinoma, superficial and nodular type\xa0'
#  '\xa0 mildly dysplastic compound melanocytic nevus'
#  'basal cell carcinoma, nodular type, excised on plane of section examined'
#  'compound melanocytic nevus, focally\xa0'
#  '-- \xa0 invasive melanoma, superficial spreading type (see comment) \xa0 \xa0\xa0 \xa0 -- \xa0 invasive component transected at the deep margin \xa0 \xa0\xa0 \xa0 -- \xa0 in situ component excised on plane of section examined \xa0 \xa0\xa0 \xa0 -- \xa0 breslow depth: at least 0.7 mm \xa0 \xa0\xa0 \xa0 -- \xa0 mitotic index: 0/mm2 \xa0 \xa0\xa0 \xa0 -- \xa0 ulceration: absent'
#  'pigmented seborrheic keratosis \xa0 adjacent squamous cell carcinoma, in situ\xa0'
#  'hyperplastic actinic keratosis with adjacent \xa0 focal dermal scar\xa0'
#  '\xa0basal cell carcinoma, superficial and nodular \xa0 type, focally transected at the deep margin\xa0'
#  'basal cell carcinoma, superficial type, \xa0 excised\xa0'
#  'basal cell carcinoma, nodular type, focally \xa0 transected at the deep margin\xa0'
#  '\xa0pigement seborrheic keratosis\xa0' 'angioma'
#  'intradermal melanocytic nevus, transected at \xa0 the deep margin\xa0'
#  '\xa0basal cell carcinoma, superficial and nodular \xa0 type\xa0'
#  'actinic keratosis with adjacent solar lentigo'
#  'mildly dysplastic compound melanocytic nevus, focally transected at the peripheral margin\xa0'
#  'mildly inflamed compound melanocytic nevus, focally transected at the peripheral margin\xa0'
#  'lentiginous junctional melanocytic nevus, \xa0 excised\xa0'
#  'intradermal melanocytic nevus, focally \xa0 transected at the peripheral margin\xa0'
#  'favor surface of inflamed seborrheic keratosis'
#  'pigmented actinic keratosis and adjacent pigmented seborrheic keratosis\xa0'
#  'compound melanocytic lesion, transected at all margins\xa0'
#  'at least squamous cell carcinoma, in situ, transected at all margins\xa0'
#  'basal cell carcinoma, nodular and infiltrative type\xa0'
#  'actinic keratosis and stasis changes'
#  'nevus lipomatosis superficialis\xa0'
#  'mildly dysplastic melanocytic nevus, excised on plane of section reviewed'
#  'squamous cell carcinoma, in-situ, excised\xa0'
#  'basal cell carcinoma, nodular and infiltrative type'
#  'acral compound melanocytic nevus, transected at all margins'
#  'basal cell carcinoma, superficial type, excised'
#  'favor surface of hidrocystoma\xa0'
#  'mildly dysplastic compound melanocytic nevus, focally transected at the deep margin'
#  'pigmented basal cell carcinoma' '\xa0squamous cell carcinoma, in-situ'
#  'severely dysplastic compound melanocytic \xa0 nevus with florid fibroplasia'
#  'traumatized and inflamed severely dysplastic junctional melanocytic nevus'
#  'eroded actinic keratosis with adnexal \xa0 extension\xa0'
#  'well-differentiated squamous cell carcinoma, keratoacanthoma type, transected at the deep margin'
#  'intradermal melanocytic nevus, transected at the deep margin'
#  'inflamed solar lentigo' '\xa0 lichenoid keratosis\xa0'
#  '\xa0moderately differentiated invasive squamous \xa0 cell carcinoma'
#  '\xa0solar lentigo/macular seborrheic keratosis\xa0'
#  'tumor of the follicular infundibulum\xa0'
#  'findings suspicious for the surface of a basal cell carcinoma'
#  'well-differentiated squamous cell carcinoma, keratoacanthoma type'
#  'inflamed mildly dysplastic compound melanocytic nevus, transected at the deep margin'
#  '\xa0inflamed macular seborrheic keratosis\xa0'
#  'basal cell carcinoma, infiltrative type'
#  '\xa0basal cell carcinoma, nodular type, excised' 'favor collagenoma'
#  'atypical lentiginous junctional melanocytic nevus'
#  'compound melanocytic nevus with congenital \xa0 features'
#  'invasive melanoma, lentigo maligna type\xa0'
#  '\xa0malignant melanoma in situ'
#  'severely inflamed, moderately dysplastic \xa0 compound melanocytic nevus'
#  'acanthosis with lichenoid inflammation'
#  'inflamed macular seborrheic keratosis with \xa0 underlying dermal hemorrhage\xa0'
#  'blue nevus' '\xa0dermatofibroma' '\xa0dermal scar' 'angioma\xa0'
#  'keloid' 'junctional melanocytic nevus'
#  'moderately dysplastic junctional melanocytic nevus'
#  'traumatized arterio-venous hemangioma'
#  'traumatized, mildly dysplastic compound \xa0 melanocytic nevus'
#  '\xa0squamous cell carcinoma, at least in situ\xa0'
#  'severely dysplastic compound melanocytic \xa0 nevus'
#  'pigmented spindle cell nevus \xa0 (reed nevus)'
#  'inflamed atypical compound melanocytic \xa0 proliferation'
#  'malignant melanoma in-situ, superficial'
#  '\xa0-- \xa0 residual/recurrent melanoma in situ, narrowly excised on plane of section examined (see comment) \xa0 -- \xa0 focal dermal scar'
#  'well-differentiated squamous cell carcinoma, \xa0 keratoacanthoma type'
#  'eroded seborrheic keratosis' 'actinic keratosis\xa0 adjacent sk'
#  'basaloid neoplasm with sebaceous differentiation, transected at all margins'
#  'irritated seborrheic keratosis'
#  'malignant melanoma in situ, superficial spreading type'
#  'mildly dysplastic junctional melanocytic nevus'
#  'melanoma in situ, lentigo maligna type'
#  'pigmented basal cell carcinoma, nodular type, \xa0 transected at all margins\xa0'
#  'lichenoid interface dermatitis with prominent pigment dropout (see comment)'
#  'epidermal ulceration with granulation tissue and acute and chronic inflammation (see comment)'
#  'basal cell carcinoma, \xa0 superficial and nodular type'
#  'basal cell carcinoma, nodular and \xa0 infiltrative type'
#  'findings consistent with ruptured \xa0 follicle/epidermal cyst with dermal scar'
#  'inflamed macular seborrheic keratosis'
#  'findings consistent with ruptured follicle/epidermal cyst' '0'
#  'prominent pigment dropout with single dyskeratotic keratinocyte and altered papillary dermal collagen, favor resolving lichenoid/interface process (see comment)'
#  '\xa0--actinic keratosis with focal dermal scar\xa0 --adjacent seborrheic keratosis'
#  'malignant melanoma in situ, superficial \xa0 spreading type'
#  'favor cutaneous lymphoid hyperplasia\xa0'
#  'malignant melanoma, lentigo maligna type (see comment)'
#  'invasive melanoma, superficial spreading type (see comment)'
#  'melanoma in situ, superficial spreading type, excised on plane of section reviewed; arising in a melanocytic nevus, excised \xa0 on plane of section reviewed'
#  'atypical junctional melanocytic \xa0 proliferation, excised on plane of section reviewed'
#  'invasive squamous cell carcinoma, narrowly excised'
#  'hyperplastic actinic keratosis, transected at \xa0 the peripheral margin\xa0'
#  'inflamed mildly dysplastic compound \xa0 melanocytic nevus, excised on plane of section reviewed'
#  'inflamed actinic keratosis'
#  'malignant melanoma in situ, superficial \xa0 spreading type, narrowly excised on plane of section reviewed\xa0'
#  'compound melanocytic nevus, excised on plane of section reviewed'
#  'invasive melanoma, superficial spreading type (see \xa0 comment)\xa0'
#  'malignant melanoma in situ, transected at the peripheral margin'
#  'favor primary cutaneous adnexal neoplasm (see comment)'
#  'epidermal acanthosis with neutrophilic serum \xa0 crust and underlying mixed inflammation (see comment)'
#  'severely dysplastic junctional melanocytic \xa0 nevus with aberrant prame expression, excised on plane of section \xa0 examined (see comment)'
#  'severely dysplastic compound melanocytic \xa0 nevus with regression, transected at the peripheral margin (see comment)'
#  'compound melanocytic nevus with congenital \xa0 features, transected at the deep margin'
#  'inflamed moderately dysplastic compound \xa0 melanocytic nevus, excised on plane of section reviewed'
#  'malignant melanoma in situ, excised on plane of section reviewed'
#  'severely dysplastic compound melanocytic \xa0 nevus, excised on plane of section reviewed'
#  'ulcerated and inflamed actinic keratosis with \xa0 adnexal extension'
#  '-- \xa0 invasive melanoma, lentigo maligna type (see comment) \xa0 \xa0\xa0 \xa0 -- \xa0 invasive component narrowly excised on plane of section \xa0 -- \xa0 in situ component transected at all margins \xa0 -- \xa0 breslow depth: 0.4 mm \xa0 -- \xa0 mitotic index: 0/mm2 \xa0 -- \xa0 ulceration: absent'
#  '-- \xa0 invasive melanoma, superficial spreading type (see \xa0 comment) \xa0 \xa0\xa0 \xa0 -- \xa0 invasive component excised on plane of section examined \xa0 \xa0\xa0 \xa0 -- \xa0 in situ component excised on plane of section examined \xa0 \xa0\xa0 \xa0 -- \xa0 breslow depth: 0.2 mm \xa0 \xa0\xa0 \xa0 -- \xa0 mitotic index: 0/mm2 \xa0 \xa0\xa0 \xa0 -- \xa0 ulceration: absent'
#  'traumatized intradermal melanocytic nevus, \xa0 transected at the deep margin'
#  '\xa0-- \xa0invasive squamous cell carcinoma \xa0 -- \xa0overlying seborrheic keratosis\xa0'
#  'malignant melanoma in situ, lentigo maligna type, transected at the peripheral and deep margins (along adnexal \xa0 structures) (see comment)'
#  '-- \xa0 invasive melanoma, superficial spreading type (see comment) \xa0 \xa0\xa0 \xa0 -- \xa0 invasive component excised on plane of section \xa0 \xa0\xa0 \xa0 -- \xa0 in situ component transected at the peripheral margin \xa0 \xa0\xa0 \xa0 -- \xa0 breslow depth: 0.4 mm \xa0 \xa0\xa0 \xa0 -- \xa0 mitotic index: 0/mm2 \xa0 \xa0\xa0 \xa0 -- \xa0 ulceration: absent \xa0 \xa0\xa0 \xa0 -- \xa0 incidental neurofibroma \xa0 \xa0\xa0 \xa0 -- \xa0 incidental intradermal melanocytic nevus, transected at the deep margin'
#  'basal cell carcinoma, infundibulocystic type'
#  'squamous cell carcinoma, at least in situ' 'inflamed verruca vulgaris'
#  'pigmented macular seborrheic keratosis, \xa0 focally transected at the peripheral margin'
#  'compound melanocytic nevus with congenital features, transected at the deep margin'
#  'hypertrophic scar' 'ulcerated actinic keratosis'
#  '\xa0-- \xa0 invasive melanoma, superficial spreading type (see comment) \xa0 \xa0\xa0 \xa0 \xa0-- \xa0invasive component excised on plane of section examined \xa0 \xa0\xa0 \xa0 -- \xa0 in situ component transected at the peripheral margin'
#  'arterio-venous hemangioma'
#  'atypical compound melanocytic proliferation, worrisome for early/evolving melanoma in situ, focally transected at the peripheral margin, with associated melanocytic nevus, excised on \xa0 plane of section examined'
#  'blue nevus, excised on plane of section \xa0 reviewed'
#  'compound melanocytic nevus, narrowly excised'
#  'mildly dysplastic compound melanocytic nevus, focally transected at the peripheral margin'
#  'mild epidermal acanthosis and sparse chronic inflammatory infiltrate'
#  '\xa0-- \xa0 \xa0 \xa0 \xa0 \xa0severely dysplastic compound melanocytic nevus, transected at the peripheral margin (see comment) \xa0 \xa0\xa0 \xa0 \xa0 \xa0 \xa0 -- \xa0 \xa0 \xa0 \xa0 \xa0superimposed spongiotic dermatitis (see comment)'
#  'invasive squamous cell carcinoma (see comment)'
#  'basal cell carcinoma, superficial type (see \xa0 comment)'
#  'follicular cyst (infundibular type) with \xa0 adjacent dermal scar'
#  'mildly dysplastic junctional melanocytic \xa0 nevus, excised on plane of section reviewed (see comment)\xa0'
#  'cytologically bland adnexal neoplasm' 'angiokeratoma'
#  'malignant melanoma in situ, superficial \xa0 spreading type, narrowly excised'
#  'folliculitis with bacterial organisms \xa0 identified within follicular ostium (see comment)'
#  'severely atypical melanocytic nevus, transected at the \xa0 peripheral margin (see comment)'
#  'moderately dysplastic compound melanocytic \xa0 nevus, transected at the peripheral margin (see comment)'
#  'compound melanocytic nevus, transected at the \xa0 deep margin'
#  'basal cell carcinoma, superficial and \xa0 infiltrative types'
#  'intradermal melanocytic nevus, transected at \xa0 the deep margin'
#  'melanoma in situ, superficial spreading type, transected at the peripheral margin'
#  'basal cell carcinoma, mixed nodular and \xa0 micronodular growth pattern'
#  'macular seborrheic keratosis (see comment)'
#  'traumatized and inflamed macular seborrheic keratosis\xa0'
#  'compound melanocytic nevus, transected at the deep margin' 'acrochordon'
#  'granulation tissue with mixed inflammation \xa0 and fibrinopurulent debris (see comment)'
#  'findings consistent with ruptured \xa0 follicle/epidermal cyst'
#  'eroded and inflamed actinic keratosis'
#  'basal cell carcinoma, superficial and nodular type; adjacent actinic keratosis'
#  'mildly dysplastic compound melanocytic nevus, \xa0 narrowly excised on plane of section reviewed'
#  'inflamed lentiginous compound melanocytic nevus, excised'
#  'spongiotic dermatitis (see comment)'
#  'pigmented seborrheic keratosis, transected at the peripheral margin'
#  'basal cell carcinoma, superficial and nodular type, excised'
#  'consistent with resolving/involuting keratoacanthoma'
#  'malignant melanoma in situ, acral lentiginous type'
#  'malignant melanoma in situ, acral lentiginous'
#  'glomangioma/glomus tumor, transected at the deep margins'
#  'fibrous papule'
#  'melanoma in situ, lentigo maligna type, transected at the peripheral margin (see comment)'
#  'melanocytoma with nevocellular and deep penetrating nevus components, transected at the deep margin (see comment)'
#  '\xa0-- inflamed verruca vulgaris\xa0 -- adjacent macular seborrheic keratosis'
#  'compound melanocytic nevus, transected at all margins'
#  'inflamed moderately dysplastic compound melanocytic nevus, excised on plane of section reviewed'
#  'hypertrophic actinic keratosis, transected at the deep margin'
#  'combined atypical nevocellular and blue nevus, transected at the deep margin (see comment)'
#  '\xa0-- \xa0 invasive melanoma, superficial spreading type (see comment) \xa0 \xa0\xa0 \xa0 -- \xa0 invasive component excised \xa0 \xa0\xa0 \xa0 -- \xa0 in situ component narrowly excised on plane of section reviewed'
#  'epidermal acanthosis with underlying fibrosis and cytologically bland veno-lymphatic vessels (see comment)'
#  'severely dysplastic junctional melanocytic \xa0 nevus, narrowly excised on plane of section reviewed (see comment)'
#  'severely dysplastic compound melanocytic nevus, transected at the peripheral margin (see comment)'
#  'solar lentigo with underlying hemorrhage'
#  'compound melanocytic nevus with congenital features, transected at all margins'
#  'pigmented basal cell carcinoma, nodular type, narrowly excised on plane of section reviewed'
#  'adnexal neoplasm, favor surface of syringoma (see comment)'
#  'hyperplastic actinic keratosis with adnexal \xa0 extension'
#  'basal cell carcinoma, nodular type, narrowly excised'
#  '\xa0-- \xa0 malignant melanoma in-situ, superficial spreading type, excised on plane of section examined (see comment) \xa0 \xa0\xa0 \xa0 -- \xa0 arising in association with a compound melanocytic nevus, excised on plane of section examined'
#  'malignant melanoma in-situ, superficial \xa0 spreading type, arising in a dysplastic compound melanocytic nevus, excised on plane of section examined (see comment)'
#  'malignant melanoma in-situ, superficial \xa0 spreading type, arising in a dysplastic compound melanocytic nevus, transected at all margins (see comment)'
#  'severely atypical compound melanocytic nevus, transected at all margins (see comment)'
#  '\xa0-- \xa0 \xa0 \xa0 \xa0 \xa0mildly dysplastic junctional melanocytic nevus, excised on plane of section reviewed (see comment) \xa0 \xa0\xa0 \xa0 \xa0 \xa0 \xa0 -- \xa0 \xa0 \xa0 \xa0 \xa0adjacent intradermal melanocytic nevus, transected at the deep margin'
#  'atypical compound melanocytic proliferation, favor severely atypical spitz nevus'
#  '-- \xa0 invasive melanoma, superficial spreading type (see comment) \xa0 \xa0\xa0 \xa0 -- \xa0 invasive component present in specimen tips \xa0 \xa0\xa0 \xa0 -- \xa0 in situ component present in specimen tips \xa0 \xa0\xa0 \xa0 -- \xa0 breslow depth: 0.5 mm \xa0 \xa0\xa0 \xa0 -- \xa0 mitotic index: 0/mm2 \xa0 \xa0\xa0 \xa0 -- \xa0 ulceration: absent'
#  'moderately dysplastic compound melanocytic nevus, excised on plane of section reviewed'
#  'malignant melanoma in situ-superficial spreading, transected at the peripheral margin (see comment)'
#  'epidermal ulceration with acute and chronic inflammation (see comment)'
#  'intradermal melanocytic nevus with congenital features, transected at the deep margin'
#  'inflamed mildly dysplastic compound \xa0 melanocytic nevus, excised on plane of section reviewed (see comment)'
#  'moderately dysplastic compound melanocytic nevus, focally transected at the peripheral margin \xa0and at the deep margin (see comment)'
#  'inflamed moderately dysplastic compound \xa0 melanocytic nevus, narrowly excised on plane of section examined (see comment)'
#  'well-differentiated invasive squamous cell carcinoma, transected at the deep margin (see comment)'
#  '-- \xa0 invasive melanoma, superficial spreading type (see comment) \xa0 \xa0\xa0 \xa0 -- \xa0 invasive component excised on plane of section examined \xa0 \xa0\xa0 \xa0 -- \xa0 in situ component transected at the peripheral margin \xa0 \xa0\xa0 \xa0 -- \xa0 breslow depth: 0.4 mm \xa0 \xa0\xa0 \xa0 -- \xa0 mitotic index: 0/mm2 \xa0 \xa0\xa0 \xa0 -- \xa0 ulceration: absent \xa0 \xa0\xa0 \xa0 -- \xa0 associated melanocytic nevus, transected at the deep margin'
#  'inflamed intradermal melanocytic nevus, \xa0 transected at the deep margin'
#  'moderately dysplastic compound melanocytic nevus, excised on plane of section reviewed (see comment)'
#  'lentiginous junctional melanocytic nevus with mild atypia, excised on plane of section examined (see comment)'
#  'moderately dysplastic compound melanocytic nevus, excised'
#  'malignant melanoma in situ, superficial \xa0 spreading type, excised (see comment)'
#  'severely dysplastic compound melanocytic nevus, narrowly excised on plane of section examined (see comment)'
#  '\xa0-- \xa0 \xa0 \xa0 \xa0 \xa0mildly dysplastic compound melanocytic nevus, excised on plane of section reviewed \xa0 -- \xa0 \xa0 \xa0 \xa0 \xa0incidental angioma'
#  'squamous cell carcinoma, in-situ, transected at the deep margin'
#  'compound melanocytic nevus with \xa0 persistent/recurrent features, transected at all margins'
#  '-- \xa0invasive melanoma, nevoid type (see comment) \xa0 \xa0\xa0 \xa0 -- \xa0 invasive component focally transected at the deep margin \xa0 \xa0\xa0 \xa0 -- \xa0 in situ component excised \xa0 \xa0\xa0 \xa0 -- \xa0 breslow depth at least 3.0 mm \xa0 \xa0\xa0 \xa0 -- \xa0 mitotic index: 0/mm2'
#  'severely dysplastic compound melanocytic \xa0 nevus, focally transected at the deep margin'
#  'melanoma in situ, lentigo maligna type, \xa0 transected at the peripheral margin'
#  'atypical compound melanocytic proliferation, favor atypical compound melanocytic nevus with fibrosis,\xa0 transected at the peripheral margin'
#  'neurofibroma'
#  'mildly dysplastic junctional melanocytic nevus, excised on plane of section examined'
#  'favor solar lentigo'
#  'cellular dermatofibroma, transected at all margins'
#  '-- \xa0 \xa0 \xa0 \xa0 \xa0invasive melanoma, superficial spreading type (see comment) \xa0 \xa0\xa0 \xa0 \xa0 \xa0 \xa0 \xa0-- \xa0 \xa0 \xa0 \xa0 \xa0invasive melanoma excised \xa0 \xa0\xa0 \xa0 -- \xa0 \xa0melanoma in situ transected at the peripheral margin \xa0 \xa0\xa0 \xa0 \xa0 \xa0 \xa0 \xa0-- \xa0 \xa0 \xa0 \xa0 \xa0breslow depth 0.4 mm \xa0 \xa0\xa0 \xa0 \xa0 \xa0 \xa0 \xa0-- \xa0 \xa0 \xa0 \xa0 \xa0mitotic index: 0/mm2 \xa0 \xa0\xa0 \xa0 \xa0 \xa0 \xa0 \xa0-- \xa0 \xa0 \xa0 \xa0 \xa0ulceration absent'
#  'solar lentigo, transected at the peripheral margin'
#  '-- \xa0 invasive melanoma, superficial spreading type (see comment) \xa0 \xa0\xa0 \xa0 -- \xa0 invasive component excised \xa0 \xa0\xa0 \xa0 -- \xa0 in situ component excised \xa0 \xa0\xa0 \xa0 -- \xa0 breslow depth 0.5 mm \xa0 \xa0\xa0 \xa0 -- \xa0 mitotic index: 0/mm2 \xa0 \xa0\xa0 \xa0 -- \xa0 ulceration absent'
#  'findings consistent with ruptured follicle/folliculitis'
#  'severely dysplastic compound melanocytic \xa0 nevus, narrowly excised on plane of section reviewed'
#  'macular seborrheic keratosis underlying \xa0 dermal hemorrhage, compatible with ecchymosis'
#  'moderately dysplastic compound melanocytic nevus, transected at the peripheral margin'
#  'atypical compound melanocytic proliferation, favor malignant melanoma in situ arising in a compound nevus, excised (see comment)'
#  'palisaded encapsulated neuroma'
#  'squamous cell carcinoma, in-situ, transected at the peripheral margin'
#  'atypical squamous proliferation, broadly \xa0 transected at the base'
#  '\xa0-- \xa0 \xa0 \xa0 \xa0 \xa0actinic keratosis with adnexal extension \xa0 -- \xa0 \xa0 \xa0 \xa0 \xa0sebaceous hyperplasia'
#  '\xa0-- \xa0 \xa0 \xa0 \xa0 \xa0invasive melanoma, nevoid type (see comment) \xa0 -- \xa0 \xa0 \xa0 \xa0 associated intradermal nevus, excised on plane of section examined'
#  'junctional melanocytic nevus, excised on plane of section reviewed'
#  'dermatofibroma, transected at the deep margin'
#  'severely dysplastic junctional melanocytic \xa0 nevus, transected at the peripheral margin\xa0'
#  'moderately differentiated invasive squamous \xa0 cell carcinoma, transected at all margins'
#  'melanoma in situ, superficial spreading type, \xa0 narrowly excised (see comment) \xa0 \xa0\xa0 \xa0 \xa0 \xa0 \xa0 -- \xa0 \xa0 \xa0 \xa0 \xa0associated intradermal melanocytic nevus, \xa0 excised'
#  'atypical squamous proliferation, favor surface of invasive squamous cell carcinoma'
#  'basal cell carcinoma, nodular and infiltrative types'
#  'severely dysplastic compound melanocytic nevus'
#  '\xa0intradermal melanocytic nevus with congenital \xa0 features'
#  'digital fibrokeratoma'
#  'basal cell carcinoma, mixed nodular and micronodular growth pattern'
#  'inflamed mildly dysplastic junctional melanocytic nevus'
#  'folliculitis with rupture'
#  'malignant melanoma in-situ, lentigo maligna type'
#  'at least squamous cell carcinoma, in situ'
#  'inflamed and impetiginized seborrheic keratosis'
#  'sebaceous hyperplasia with adjacent actinic keratosis'
#  'severely dysplastic compound melanocytic nevus, narrowly excised on plane of section reviewed'
#  'severely dysplastic compound melanocytic nevus with focal regression, transected at the peripheral margin'
#  'severely dysplastic compound melanocytic nevus, excised on plane of section reviewed'
#  'residual recurrent invasive melanoma'
#  'invasive malignant melanoma, lentigo maligna type\xa0'
#  'intradermal melanocytic nevus, excised'
#  'malignant melanoma in-situ, lentigo maligna type, transected at the peripheral margin']
